# %%
# %%time

# %run ImbalancedLearningRL/ImbalancedLearningRL/run.py
# Out:
# Reward for each class label.
# 	- Class 0 : 0.4928
# 	- Class 1 : 0.8701
# Start training
# Training Scores
# train_step : 1000, epsilon : 0.010
# num samples: 1000
# Test results
# Accuracy: 0.664
# Recall: 0.435
# Precision: 0.352
# Specificity: 0.739
# F1 Score: 0.389
# PPV: 0.352
# NPV: 0.800
# AUC: 0.653
#
#
# Validation Scores
# train_step : 1000, epsilon : 0.010
# num samples: 9769
# Test results
# Accuracy: 0.713
# Recall: 0.433
# Precision: 0.401
# Specificity: 0.800
# F1 Score: 0.416
# PPV: 0.401
# NPV: 0.820
# AUC: 0.688
#
#
# Training Scores
# train_step : 2000, epsilon : 0.010
# num samples: 2000
# Test results
# Accuracy: 0.689
# Recall: 0.458
# Precision: 0.391
# Specificity: 0.765
# F1 Score: 0.422
# PPV: 0.391
# NPV: 0.811
# AUC: 0.693
#
#
# Validation Scores
# train_step : 2000, epsilon : 0.010
# num samples: 9769
# Test results
# Accuracy: 0.728
# Recall: 0.447
# Precision: 0.428
# Specificity: 0.815
# F1 Score: 0.437
# PPV: 0.428
# NPV: 0.827
# AUC: 0.729
#
#
# ...
